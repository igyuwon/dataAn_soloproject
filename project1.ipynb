# %% [markdown]
# # 1차 프로젝트 : Adidas 미국 판매데이터 분석-파트 1

# %% [markdown]
# ## (1) 데이터 로드 및 확인

# %%
import pandas as pd
import numpy as np

adidas  = pd.read_csv('./data/Adidas US Sales Datasets.csv')
adidas.head(2)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     2020.1.1  Northeast  New York  New York
# 1  Foot Locker      1185732     2020.1.2  Northeast  New York  New York
#
#                    Product Price per Unit Units Sold Total Sales  \
# 0    Men's Street Footwear        $50.00       1,200   $600,000
# 1  Men's Athletic Footwear        $50.00       1,000   $500,000
#
#   Operating Profit Operating Margin Sales Method
# 0        $300,000               50%     In-store
# 1        $150,000               30%     In-store

# %%
adidas['Sales Method'].unique()
# Out:
# array(['In-store', 'Outlet', 'Online'], dtype=object)

# %% [markdown]
# Retailer : adidas 브랜드를 판매하는 유통처
#
# Retailer ID : 판매점 ID
#
# Price per Unit : 상품 1개당 가격
#
# Units Sold : 판매수량
#
# Total Sales	: 판매금액
#
# Operating Profit : 영업이익(매출액 - 원가)
#
# Operating Margin : 영업마진(영업이익율)

# %%
adidas.info() # 데이터타입 조회
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 980.0+ KB

# %% [markdown]
# ## (2) 데이터 전처리

# %% [markdown]
# 데이터 타입 변환

# %% [markdown]
# Retailer,Region,State,City,Product,Sales Method / object
#
# Retailer ID int64 -> 문자
#
# Invoice Date object -> 날짜
#
# Price per Unit object -> 숫자(실수, float)
#
# Units Sold -> 숫자(실수, float)
#
# Total Sales -> 숫자(실수, float)
#
# Operating Profit -> 숫자(실수, float)
#
# Operating Margin -> 숫자(실수, float)

# %% [markdown]
# ## 1) 숫자가 문자로 나타난 경우 문자를 숫자로 변환

# %%
# 컬럼별 데이터 변환

adidas['Price per Unit'] = adidas['Price per Unit'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
adidas['Units Sold'] = adidas['Units Sold'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
adidas['Total Sales'] = adidas['Total Sales'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
adidas['Operating Profit'] = adidas['Operating Profit'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
adidas['Operating Margin'] = adidas['Operating Margin'].str.replace('[\$,%]', '', regex=True).str.strip().astype('float')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# <>:6: SyntaxWarning: invalid escape sequence '\$'
# <>:7: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# <>:6: SyntaxWarning: invalid escape sequence '\$'
# <>:7: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/tl/wnyyz7fn52lb2wsy5gd0gwfw0000gn/T/ipykernel_31645/227458644.py:3: SyntaxWarning: invalid escape sequence '\$'
#   adidas['Price per Unit'] = adidas['Price per Unit'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
# /var/folders/tl/wnyyz7fn52lb2wsy5gd0gwfw0000gn/T/ipykernel_31645/227458644.py:4: SyntaxWarning: invalid escape sequence '\$'
#   adidas['Units Sold'] = adidas['Units Sold'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
# /var/folders/tl/wnyyz7fn52lb2wsy5gd0gwfw0000gn/T/ipykernel_31645/227458644.py:5: SyntaxWarning: invalid escape sequence '\$'
#   adidas['Total Sales'] = adidas['Total Sales'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
# /var/folders/tl/wnyyz7fn52lb2wsy5gd0gwfw0000gn/T/ipykernel_31645/227458644.py:6: SyntaxWarning: invalid escape sequence '\$'
#   adidas['Operating Profit'] = adidas['Operating Profit'].str.replace('[\$,]', '', regex=True).str.strip().astype('float')
# /var/folders/tl/wnyyz7fn52lb2wsy5gd0gwfw0000gn/T/ipykernel_31645/227458644.py:7: SyntaxWarning: invalid escape sequence '\$'
#   adidas['Operating Margin'] = adidas['Operating Margin'].str.replace('[\$,%]', '', regex=True).str.strip().astype('float')

# %%
adidas.head(5)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     2020.1.1  Northeast  New York  New York
# 1  Foot Locker      1185732     2020.1.2  Northeast  New York  New York
# 2  Foot Locker      1185732     2020.1.3  Northeast  New York  New York
# 3  Foot Locker      1185732     2020.1.4  Northeast  New York  New York
# 4  Foot Locker      1185732     2020.1.5  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0          300000.0              50.0     In-store
# 1          150000.0              30.0     In-store
# 2          140000.0              35.0     In-store
# 3          133875.0              35.0     In-store
# 4          162000.0              30.0     In-store

# %% [markdown]
# Operating Margin은 백분율이기 때문에 0.01을 곱하여 계산에 사용할 수 있도록 새로운 변수 생성

# %%
adidas['Operating_Margin_rate'] = adidas['Operating Margin']*0.01
adidas.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     2020.1.1  Northeast  New York  New York
# 1  Foot Locker      1185732     2020.1.2  Northeast  New York  New York
# 2  Foot Locker      1185732     2020.1.3  Northeast  New York  New York
# 3  Foot Locker      1185732     2020.1.4  Northeast  New York  New York
# 4  Foot Locker      1185732     2020.1.5  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit  Operating Margin Sales Method  Operating_Margin_rate
# 0          300000.0              50.0     In-store                   0.50
# 1          150000.0              30.0     In-store                   0.30
# 2          140000.0              35.0     In-store                   0.35
# 3          133875.0              35.0     In-store                   0.35
# 4          162000.0              30.0     In-store                   0.30

# %% [markdown]
# ## 2) Pandas 시간 데이터 다루기
# YYYY.mm.dd 형태의 문자 데이터를 pandas의 datetime으로 변환
#
# '%Y.%m.%d'

# %%
adidas['Invoice Date'] = pd.to_datetime(adidas['Invoice Date'], format='%Y.%m.%d')
